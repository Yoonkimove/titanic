# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
train = pd.read_csv('all/train.csv')
test = pd.read_csv('all/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
train.pivot_table(index=['Sex'], values=['Survived'])
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
columns = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train['Survived'] = train

# %%
(ggplot(train)
 + aes(x='Pclass', y='Age', fill='Embarked')
 + geom_col()
)
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/plotnine/layer.py:433: UserWarning: position_stack : Removed 177 rows containing missing values.
#   data = self.position.setup_data(self.data, params)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     for idx,output_line in enumerate(output.splitlines()):
#     697         if idx:
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in __repr__(self)
#      95         # in the jupyter notebook.
#      96         if not self.figure:
# ---> 97             self.draw()
#      98         plt.show()
#      99         return '<ggplot: (%d)>' % self.__hash__()
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in draw(self, return_ggplot)
#     188         # new frames knowing that they are separate from the original.
#     189         with pd.option_context('mode.chained_assignment', None):
# --> 190             return self._draw(return_ggplot)
#     191
#     192     def _draw(self, return_ggplot=False):
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     219             if self.figure is not None:
#     220                 plt.close(self.figure)
# --> 221             raise err
#     222
#     223         if return_ggplot:
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     211                 self._draw_facet_labels()
#     212                 self._draw_labels()
# --> 213                 self._draw_legend()
#     214                 self._draw_title()
#     215                 self._draw_watermarks()
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in _draw_legend(self)
#     414         Draw legend onto the figure
#     415         """
# --> 416         legend_box = self.guides.build(self)
#     417         if not legend_box:
#     418             return
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/guides/guides.py in build(self, plot)
#     134             self.spacing = 10
#     135
# --> 136         gdefs = self.train(plot)
#     137         if not gdefs:
#     138             return
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/guides/guides.py in train(self, plot)
#     204             # so Guides (i.e., the container of guides)
#     205             # need not to know about them
# --> 206             guide = guide.train(scale)
#     207
#     208             if guide is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/guides/guide_legend.py in train(self, scale)
#      81
#      82         key = pd.DataFrame({
# ---> 83             scale.aesthetics[0]: scale.map(breaks),
#      84             'label': scale.get_labels(breaks)})
#      85
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/scales/scale.py in map(self, x, limits)
#     298         else:
#     299             pal = np.asarray(pal)
# --> 300             pal_match = pal[match(x, limits)]
#     301             bool_idx = pd.isnull(pal_match)
#     302             if np.any(bool_idx):
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived')
 + geom_col()
 + ggtitle('성별 생존률')
 + theme(text=element_text(family='NanumBarunGothic'))
)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null object
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.6+ KB

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived', fill='Embarked')
 + geom_col()
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     for idx,output_line in enumerate(output.splitlines()):
#     697         if idx:
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in __repr__(self)
#      95         # in the jupyter notebook.
#      96         if not self.figure:
# ---> 97             self.draw()
#      98         plt.show()
#      99         return '<ggplot: (%d)>' % self.__hash__()
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in draw(self, return_ggplot)
#     188         # new frames knowing that they are separate from the original.
#     189         with pd.option_context('mode.chained_assignment', None):
# --> 190             return self._draw(return_ggplot)
#     191
#     192     def _draw(self, return_ggplot=False):
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     219             if self.figure is not None:
#     220                 plt.close(self.figure)
# --> 221             raise err
#     222
#     223         if return_ggplot:
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     211                 self._draw_facet_labels()
#     212                 self._draw_labels()
# --> 213                 self._draw_legend()
#     214                 self._draw_title()
#     215                 self._draw_watermarks()
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/ggplot.py in _draw_legend(self)
#     414         Draw legend onto the figure
#     415         """
# --> 416         legend_box = self.guides.build(self)
#     417         if not legend_box:
#     418             return
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/guides/guides.py in build(self, plot)
#     134             self.spacing = 10
#     135
# --> 136         gdefs = self.train(plot)
#     137         if not gdefs:
#     138             return
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/guides/guides.py in train(self, plot)
#     204             # so Guides (i.e., the container of guides)
#     205             # need not to know about them
# --> 206             guide = guide.train(scale)
#     207
#     208             if guide is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/guides/guide_legend.py in train(self, scale)
#      81
#      82         key = pd.DataFrame({
# ---> 83             scale.aesthetics[0]: scale.map(breaks),
#      84             'label': scale.get_labels(breaks)})
#      85
#
# ~/anaconda3/lib/python3.6/site-packages/plotnine/scales/scale.py in map(self, x, limits)
#     298         else:
#     299             pal = np.asarray(pal)
# --> 300             pal_match = pal[match(x, limits)]
#     301             bool_idx = pd.isnull(pal_match)
#     302             if np.any(bool_idx):
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
(ggplot(train)
 + aes(x='Age', y='Fare', fill='Pclass')
 + geom_point()
 + ggtitle('생존 여부별 성별 요금 등급 분포')
 + facet_wrap('~Survived')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 177 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (-9223372029313272481)>

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived', fill='Embarked')
 + geom_col()
 + ggtitle('생존 여부별 성별 요금 등급 분포')
 + facet_wrap('~Survived')
 + theme(text=element_text(family='NanumBarunGothic'))
)

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived', fill='Embarked')
 + geom_col()
 + ggtitle('생존 여부별 성별 요금 등급 분포')
 + facet_wrap('~Survived')
 + theme(text=element_text(family='NanumBarunGothic'))
)

# %%
train['Age'] = train['Age'].dropna()

# %%
train.dropna?

# %%
# !pip install missingno

# %%
import missingno as msno

msno.matrix(train)

# %%
train['Embarked'] = train['Embarked'].dropna()
